# %% [markdown]
# ## HW 3

# %% [markdown]
# 1) Analysis of the blood_cell image
# 2.0 Read the blood cell image into a numpy matrix im.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img=mpimg.imread('blood_cell.png')
plt.imshow(img)
img.shape
# Out:
# (739, 1024, 3)

# %% [markdown]
# 2.1 Display  im (matplotlib).

# %%
from PIL import Image
import numpy as np

w, h = 512, 512
data = np.zeros((h, w, 3), dtype=np.uint8)
data[256, 256] = [255, 0, 0]
img = Image.fromarray(data, 'RGB')
img.save('blood_cell.png.png')
img.show()

# %%
2.2 Separate im into 3 channels.

# %%
2.3 Print the min, max, mode, median, mean, var, std of red, green, blue channels

# %%
 img.min(),img.max(), img.mean()
# Out:
# (0.8686953, 1.0, 0.0)

# %%
2.4  Display the histogram of green channel

# %%
r = img[:,:,1]
h, bins,_ = plt.hist(np.ndarray.flatten(r),20)
'''bins = np.linspace(np.min(r),np.max(r),20)
print(bins)
h = np.histogram(r, bins)
print(h[0].shape)
plt.bar(bins,h[0])'''
plt.imshow(ar_2d, cmap = 'green')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-aa350e70c581> in <module>
# ----> 1 r = img[:,:,1]
#       2 h, bins,_ = plt.hist(np.ndarray.flatten(r),20)
#       3 '''bins = np.linspace(np.min(r),np.max(r),20)
#       4 print(bins)
#       5 h = np.histogram(r, bins)
#
# TypeError: 'Image' object is not subscriptable

# %%
2.5  We would like to create a binary mask of foreground cells. Binary mask is a matrix of image widthxheight where the foreground values are 1 and background values are 0. 
     To solve this, inspect the green channel of the image. Inspect the histogram to understand the foreground pixel values, and background pixel values.  
  
     Threshold the image im_fg = im_green<threshold to create the binary mask.

# %%
2.6  Then calculate the mean of only the foreground image for red,green,blue channels and std for red, green, blue channels.

# %%
2.7 Repeat above (2.5,2.6) to calculate a binary mask for WBC (in the center).
