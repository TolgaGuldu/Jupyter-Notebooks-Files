# %% [markdown]
# ### In HW 4 we will use we will explore statistical properties of data sets.
#
# ### Warning : You do not need to solve this homework with pandas, numpy or anyother library.
# ### you can get numpy arrays and do your work on numpy and stats libraries.
#
# for pandas do a tutorial first to understand the indexing
# https://pandas.pydata.org/pandas-docs/stable/getting_started/tutorials.html

# %% [markdown]
# #### 1) Car data has information about car makes, models sold in India

# %%
import pandas as pd
from pandas import Series, DataFrame
from datetime import datetime as dt
from scipy import stats
cars = pd.read_csv("cars_v1.csv", encoding = "ISO-8859-1")
print(cars.head(10)) # check the first ten rows

#Find mean of price
cars.Price.mean()
cars.Mileage.median()
#cars.groupby('Make') : Finish the code
cars.groupby('Make').Mileage.mean().reset_index()
a = 1
# Out:
#                        Make                                        Model  \
# 0       Ashok Leyland Stile        Ashok Leyland Stile LE 8-STR (Diesel)
# 1       Ashok Leyland Stile        Ashok Leyland Stile LS 8-STR (Diesel)
# 2       Ashok Leyland Stile        Ashok Leyland Stile LX 8-STR (Diesel)
# 3       Ashok Leyland Stile        Ashok Leyland Stile LS 7-STR (Diesel)
# 4       Ashok Leyland Stile  Ashok Leyland Stile LS 7-STR Alloy (Diesel)
# 5       Ashok Leyland Stile        Ashok Leyland Stile LX 7-STR (Diesel)
# 6       Ashok Leyland Stile  Ashok Leyland Stile LX 7-STR Alloy (Diesel)
# 7       Aston Martin Rapide            Aston Martin Rapide LUXE (Petrol)
# 8     Aston Martin Rapide S               Aston Martin Rapide S (Petrol)
# 9  Aston Martin V12 Vantage      Aston Martin V12 Vantage Coupe (Petrol)
#
#    Price   Type   ABS  BootSpace    GearType AirBag  Engine  FuelCapacity  \
# 0    750    MPV    No      500.0      Manual     No  1461.0          50.0
# 1    800    MPV    No      500.0      Manual     No  1461.0          50.0
# 2    830    MPV    No      500.0      Manual     No  1461.0          50.0
# 3    850    MPV    No      500.0      Manual     No  1461.0          50.0
# 4    880    MPV    No      500.0      Manual     No  1461.0          50.0
# 5    900    MPV    No      500.0      Manual     No  1461.0          50.0
# 6    930    MPV    No      500.0      Manual     No  1461.0          50.0
# 7  35000  Sedan   Yes      300.0   Automatic    Yes  5935.0          90.5
# 8  44000  Sedan   Yes        NaN   Automatic    Yes  5935.0          90.0
# 9  35000  Coupe   Yes      300.0   Automatic    Yes  5935.0          80.0
#
#    Mileage
# 0     20.7
# 1     20.7
# 2     20.7
# 3     20.7
# 4     20.7
# 5     20.7
# 6     20.7
# 7      7.0
# 8     11.9
# 9      9.0

# %% [markdown]
# #### 1a) Describe data with mean, std, modes, median, quantiles, max

# %%
cars.describe()
# Out:
#               Price    BootSpace       Engine  FuelCapacity     Mileage
# count    833.000000   654.000000   826.000000    833.000000  662.000000
# mean    3159.495798   409.536697  1900.533898     51.341693   17.480408
# std     6272.519112   175.351525  1065.149758     17.643132    4.584628
# min      199.000000    80.000000   624.000000      0.000000    5.000000
# 25%      619.000000   256.000000  1248.000000     42.000000   14.000000
# 50%      880.000000   418.000000  1497.000000     50.000000   17.985000
# 75%     2329.000000   500.000000  2179.000000     64.000000   20.700000
# max    50000.000000  1000.000000  6592.000000    120.000000   30.000000

# %%
cars.isnull().sum() # 171 cars have no Mileage information remove them.
# like numpy you use boolean indexing
# Out:
# Make              0
# Model             0
# Price             0
# Type              0
# ABS              16
# BootSpace       179
# GearType         16
# AirBag           21
# Engine            7
# FuelCapacity      0
# Mileage         171
# dtype: int64

# %% [markdown]
# #### 1b) Remove the data  which does not have mileage information (like numpy you use boolean indexing)
#
# - cars2 is cars with mileage information
# - do not forget to make a copy into cars2
# - also reset the Index so index is continuos

# %%
cars2 = pd.read_csv("cars_v1.csv", index_col ="Mileage" ) 
cars2_cleaned = cars2.dropna()
cars2_cleaned
# Out:
#                              Make  \
# Mileage
#  20.70        Ashok Leyland Stile
#  20.70        Ashok Leyland Stile
#  20.70        Ashok Leyland Stile
#  20.70        Ashok Leyland Stile
#  20.70        Ashok Leyland Stile
#  20.70        Ashok Leyland Stile
#  20.70        Ashok Leyland Stile
#  7.00         Aston Martin Rapide
#  9.00    Aston Martin V12 Vantage
#  5.00     Aston Martin V8 Vantage
#  5.00     Aston Martin V8 Vantage
#  5.00     Aston Martin V8 Vantage
#  8.00       Aston Martin Vanquish
#  17.00          Audi A3 Cabriolet
#  16.55                    Audi A4
#  15.64                    Audi A4
#  16.55                    Audi A4
#  10.34                    Audi A4
#  14.94                    Audi A4
#  17.68                    Audi A6
#  13.53                    Audi A6
#  14.57                    Audi A6
#  14.40                    Audi A7
#  15.50                  Audi A8 L
#  12.50                  Audi A8 L
#  10.30                  Audi A8 L
#  12.00                  Audi A8 L
#  17.32                    Audi Q3
#  15.73                    Audi Q3
#  15.73                    Audi Q3
# ...                           ...
#  14.30          Volkswagen Passat
#  18.78          Volkswagen Passat
#  16.47            Volkswagen Polo
#  16.47            Volkswagen Polo
#  16.47            Volkswagen Polo
#  20.14            Volkswagen Polo
#  20.14            Volkswagen Polo
#  20.14            Volkswagen Polo
#  19.70         Volkswagen Polo GT
#  17.20         Volkswagen Polo GT
#  21.00              Volkswagen Up
#  16.09           Volkswagen Vento
#  16.09           Volkswagen Vento
#  20.64           Volkswagen Vento
#  18.19           Volkswagen Vento
#  20.64           Volkswagen Vento
#  18.19           Volkswagen Vento
#  20.64           Volkswagen Vento
#  21.50           Volkswagen Vento
#  21.50           Volkswagen Vento
# NaN                     Volvo S60
#  18.50                  Volvo S60
#  20.40                  Volvo S60
#  18.50                  Volvo S60
#  16.66                  Volvo S80
# NaN                     Volvo S80
#  27.80                  Volvo V40
#  27.80                  Volvo V40
#  16.80    Volvo V40 Cross Country
#  16.00    Volvo V40 Cross Country
#
#                                                 Model  Price         Type  \
# Mileage
#  20.70          Ashok Leyland Stile LE 8-STR (Diesel)    750          MPV
#  20.70          Ashok Leyland Stile LS 8-STR (Diesel)    800          MPV
#  20.70          Ashok Leyland Stile LX 8-STR (Diesel)    830          MPV
#  20.70          Ashok Leyland Stile LS 7-STR (Diesel)    850          MPV
#  20.70    Ashok Leyland Stile LS 7-STR Alloy (Diesel)    880          MPV
#  20.70          Ashok Leyland Stile LX 7-STR (Diesel)    900          MPV
#  20.70    Ashok Leyland Stile LX 7-STR Alloy (Diesel)    930          MPV
#  7.00               Aston Martin Rapide LUXE (Petrol)  35000        Sedan
#  9.00         Aston Martin V12 Vantage Coupe (Petrol)  35000        Coupe
#  5.00          Aston Martin V8 Vantage Coupe (Petrol)  13500        Coupe
#  5.00        Aston Martin V8 Vantage S Coupe (Petrol)  25500        Coupe
#  5.00       Aston Martin V8 Vantage Roadster (Petrol)  27000        Coupe
#  8.00              Aston Martin Vanquish V12 (Petrol)  38500        Sedan
#  17.00                     Audi A3 Cabriolet (Petrol)   4475  Convertible
#  16.55                       Audi A4 2.0 TDI (Diesel)   2899        Sedan
#  15.64                      Audi A4 1.8 TFSI (Petrol)   3058        Sedan
#  16.55           Audi A4 2.0 TDI Multitronic (Diesel)   3361        Sedan
#  10.34           Audi A4 S4 3.0 TFSI quattro (Petrol)   5235        Sedan
#  14.94               Audi A4 3.0 TDI Quattro (Diesel)   5471        Sedan
#  17.68                       Audi A6 2.0 TDI (Diesel)   4356        Sedan
#  13.53              Audi A6 3.0 TFSI quattro (Petrol)   4700        Sedan
#  14.57               Audi A6 3.0 TDI quattro (Diesel)   5424        Sedan
#  14.40             Audi A7 Sportback 3.0 TDI (Diesel)   8588        Sedan
#  15.50             Audi A8 L 3.0 TDI quattro (Diesel)  10700        Sedan
#  12.50             Audi A8 L 4.2 TDI quattro (Diesel)  12300        Sedan
#  10.30             Audi A8 L 4.2 FSI quattro (Petrol)  12500        Sedan
#  12.00                         Audi A8 L W12 (Petrol)  17700        Sedan
#  17.32              Audi Q3 30 TDI S Edition (Diesel)   2899          SUV
#  15.73        Audi Q3 35 TDI Quattro Premium (Diesel)   3399          SUV
#  15.73   Audi Q3 35 TDI Quattro Premium Plus (Diesel)   3750          SUV
# ...                                               ...    ...          ...
#  14.30     Volkswagen Passat Comfortline DSG (Diesel)   2528        Sedan
#  18.78        Volkswagen Passat Highline DSG (Diesel)   2726        Sedan
#  16.47        Volkswagen Polo 1.2L Trendline (Petrol)    535    Hatchback
#  16.47      Volkswagen Polo 1.2L Comfortline (Petrol)    597    Hatchback
#  16.47         Volkswagen Polo 1.2L Highline (Petrol)    649    Hatchback
#  20.14        Volkswagen Polo 1.5L Trendline (Diesel)    670    Hatchback
#  20.14      Volkswagen Polo 1.5L Comfortline (Diesel)    733    Hatchback
#  20.14         Volkswagen Polo 1.5L Highline (Diesel)    784    Hatchback
#  19.70                Volkswagen Polo GT TDI (Diesel)    800    Hatchback
#  17.20                Volkswagen Polo GT TSI (Petrol)    850    Hatchback
#  21.00       Volkswagen Up ��� Expected Specification    360    Hatchback
#  16.09            Volkswagen Vento Trendline (Petrol)    785        Sedan
#  16.09       Volkswagen Vento Comfortline MT (Petrol)    867        Sedan
#  20.64            Volkswagen Vento Trendline (Diesel)    910        Sedan
#  18.19       Volkswagen Vento Comfortline AT (Petrol)    987        Sedan
#  20.64       Volkswagen Vento Comfortline MT (Diesel)    992        Sedan
#  18.19          Volkswagen Vento Highline AT (Petrol)   1062        Sedan
#  20.64          Volkswagen Vento Highline MT (Diesel)   1067        Sedan
#  21.50       Volkswagen Vento Comfortline AT (Diesel)   1112        Sedan
#  21.50          Volkswagen Vento Highline AT (Diesel)   1187        Sedan
# NaN                     Volvo S60 Kinetic D4 (Diesel)   3190        Sedan
#  18.50                   Volvo S60 Summum D4 (Diesel)   3390        Sedan
#  20.40                   Volvo S60 Summum D5 (Diesel)   3690        Sedan
#  18.50                                   Volvo S60 T6   4200        Sedan
#  16.66                   Volvo S80 Summum D4 (Diesel)   4135        Sedan
# NaN                      Volvo S80 Summum D5 (Diesel)   4480        Sedan
#  27.80                  Volvo V40 D3 Kinetic (Diesel)   2475    Hatchback
#  27.80                 Volvo V40 D3 R-Design (Diesel)   2770    Hatchback
#  16.80            Volvo V40 D3 Cross Country (Diesel)   3180    Hatchback
#  16.00            Volvo V40 T4 Cross Country (Petrol)   3240    Hatchback
#
#           ABS  BootSpace    GearType AirBag  Engine  FuelCapacity
# Mileage
#  20.70     No      500.0      Manual     No  1461.0          50.0
#  20.70     No      500.0      Manual     No  1461.0          50.0
#  20.70     No      500.0      Manual     No  1461.0          50.0
#  20.70     No      500.0      Manual     No  1461.0          50.0
#  20.70     No      500.0      Manual     No  1461.0          50.0
#  20.70     No      500.0      Manual     No  1461.0          50.0
#  20.70     No      500.0      Manual     No  1461.0          50.0
#  7.00     Yes      300.0   Automatic    Yes  5935.0          90.5
#  9.00     Yes      300.0   Automatic    Yes  5935.0          80.0
#  5.00     Yes      300.0   Automatic    Yes  4735.0          80.0
#  5.00     Yes      300.0   Automatic    Yes  4735.0          80.0
#  5.00     Yes      300.0   Automatic    Yes  4735.0          80.0
#  8.00     Yes      240.0   Automatic    Yes  5935.0          78.0
#  17.00    Yes      320.0   Automatic    Yes  1798.0          63.0
#  16.55    Yes      480.0   Automatic    Yes  1968.0          61.0
#  15.64    Yes      480.0   Automatic    Yes  1798.0          63.0
#  16.55    Yes      480.0   Automatic    Yes  1968.0          63.0
#  10.34    Yes      480.0   Automatic    Yes  2995.0          61.0
#  14.94    Yes      480.0   Automatic    Yes  2967.0          61.0
#  17.68    Yes      535.0   Automatic    Yes  1968.0          65.0
#  13.53    Yes      535.0   Automatic    Yes  1984.0          65.0
#  14.57    Yes      535.0   Automatic    Yes  2967.0          75.0
#  14.40    Yes      535.0   Automatic    Yes  2967.0          65.0
#  15.50    Yes      500.0   Automatic    Yes  2967.0          90.0
#  12.50    Yes      500.0   Automatic    Yes  4134.0          90.0
#  10.30    Yes      500.0   Automatic    Yes  4163.0          90.0
#  12.00    Yes      500.0   Automatic    Yes  6299.0          90.0
#  17.32    Yes      460.0      Manual     No  1968.0          64.0
#  15.73    Yes      460.0   Automatic    Yes  1968.0          64.0
#  15.73    Yes      460.0   Automatic    Yes  1968.0          64.0
# ...       ...        ...         ...    ...     ...           ...
#  14.30    Yes      565.0   Automatic    Yes  1968.0          70.0
#  18.78    Yes      565.0   Automatic    Yes  1968.0          70.0
#  16.47     No      280.0      Manual    Yes  1198.0          45.0
#  16.47    Yes      280.0      Manual    Yes  1198.0          45.0
#  16.47    Yes      280.0   Automatic    Yes  1198.0          45.0
#  20.14     No      280.0      Manual    Yes  1498.0          45.0
#  20.14    Yes      280.0      Manual    Yes  1498.0          45.0
#  20.14    Yes      280.0   Automatic    Yes  1498.0          45.0
#  19.70    Yes      250.0   Automatic    Yes  1598.0          45.0
#  17.20    Yes      250.0   Automatic    Yes  1197.0          45.0
#  21.00    Yes      220.0      Manual    Yes  1199.0          45.0
#  16.09     No      494.0      Manual     No  1598.0          55.0
#  16.09    Yes      494.0   Automatic    Yes  1598.0          55.0
#  20.64     No      494.0      Manual    Yes  1498.0          55.0
#  18.19    Yes      494.0      Manual    Yes  1197.0          55.0
#  20.64    Yes      494.0      Manual    Yes  1498.0          55.0
#  18.19    Yes      494.0   Automatic    Yes  1197.0          55.0
#  20.64    Yes      494.0      Manual    Yes  1498.0          55.0
#  21.50    Yes      494.0   Automatic    Yes  1498.0          55.0
#  21.50    Yes      494.0      Manual    Yes  1498.0          55.0
# NaN       Yes      339.0   Automatic    Yes  1984.0          67.5
#  18.50    Yes      339.0   Automatic    Yes  1984.0          67.5
#  20.40    Yes      339.0   Automatic    Yes  2400.0          67.5
#  18.50    Yes      380.0   Automatic    Yes  1969.0          67.0
#  16.66    Yes      480.0   Automatic    Yes  1984.0          70.0
# NaN       Yes      480.0   Automatic    Yes  2400.0          70.0
#  27.80    Yes      335.0   Automatic    Yes  1969.0          62.0
#  27.80    Yes      324.0   Automatic    Yes  1984.0          62.0
#  16.80    Yes      335.0   Automatic    Yes  1984.0          60.0
#  16.00    Yes      324.0   Automatic    Yes  1596.0          50.0
#
# [639 rows x 10 columns]

# %% [markdown]
# #### 1c) Display the covariance information for cars2
# What can you say covariance of engine size and mileage?

# %%
# Out:
#                      Price      BootSpace        Engine  FuelCapacity  \
# Price         3.630874e+07  179445.925571  5.470702e+06  59665.561959
# BootSpace     1.794459e+05   27132.658624  5.697838e+04   1333.667881
# Engine        5.470702e+06   56978.379702  1.150887e+06  13678.109282
# FuelCapacity  5.966556e+04    1333.667881  1.367811e+04    261.872270
# Mileage      -1.464454e+04    -252.201370 -3.442585e+03    -49.155196
#
#                    Mileage
# Price        -14644.543057
# BootSpace      -252.201370
# Engine        -3442.585057
# FuelCapacity    -49.155196
# Mileage          21.018811

# %% [markdown]
# ####  1d) Display the correlations for attributes
# Which attributes are strongly (>0.5 or <-0.5) correlated? Which two variables have maximum correlation or anti-correlation

# %%
# Out:
#                  Price  BootSpace    Engine  FuelCapacity   Mileage
# Price         1.000000   0.183640  0.844677      0.611890 -0.530110
# BootSpace     0.183640   1.000000  0.313696      0.485724 -0.329319
# Engine        0.844677   0.313696  1.000000      0.793774 -0.698500
# FuelCapacity  0.611890   0.485724  0.793774      1.000000 -0.662553
# Mileage      -0.530110  -0.329319 -0.698500     -0.662553  1.000000

# %% [markdown]
# #### Which two variables have maximum correlation or anti-correlation? Do not count self-correlations
# Plot scatter plots for those attributes

# %% [markdown]
# #### 1d) What is the mean fuel mileage for Automatic cars?
#  What is the mean fuel mileage for Manual Hatchbacks?
#
# - Be carefull that some attributes have spaces in the names. cars2.GearType==' Automatic'

# %%
# Out:
# Mean automatic:  15.745466237942123
# Mean manual:  19.112636363636362

# %% [markdown]
# #### 1e) What is the mean fuel mileage for TypeSedan cars?
#  What is the mean fuel mileage for Type Hatchbacks?

# %%
# Out:
#                      Make                                  Model  Price  \
# 7     Aston Martin Rapide      Aston Martin Rapide LUXE (Petrol)  35000
# 8   Aston Martin Rapide S         Aston Martin Rapide S (Petrol)  44000
# 13  Aston Martin Vanquish     Aston Martin Vanquish V12 (Petrol)  38500
# 14      Audi A3 Cabriolet     Audi A3 Attraction 35 TDI (Diesel)   2295
# 15      Audi A3 Cabriolet        Audi A3 Premium 35 TDI (Diesel)   2595
# 16      Audi A3 Cabriolet  Audi A3 Premium Plus 40 TFSI (Petrol)   2895
# 17      Audi A3 Cabriolet   Audi A3 Premium Plus 35 TDI (Diesel)   2995
# 18      Audi A3 Cabriolet     Audi A3 Technology 35 TDI (Diesel)   3266
# 20                Audi A4               Audi A4 2.0 TDI (Diesel)   2899
# 21                Audi A4              Audi A4 1.8 TFSI (Petrol)   3058
#
#      Type   ABS  BootSpace    GearType AirBag  Engine  FuelCapacity  Mileage
# 7   Sedan   Yes      300.0   Automatic    Yes  5935.0          90.5     7.00
# 8   Sedan   Yes        NaN   Automatic    Yes  5935.0          90.0    11.90
# 13  Sedan   Yes      240.0   Automatic    Yes  5935.0          78.0     8.00
# 14  Sedan   Yes        NaN         NaN    NaN  1968.0          50.0    20.38
# 15  Sedan   Yes        NaN         NaN    NaN  1968.0          50.0    20.38
# 16  Sedan   Yes        NaN   Automatic    Yes  1798.0          50.0    16.60
# 17  Sedan   Yes        NaN         NaN    NaN  1968.0          50.0    20.38
# 18  Sedan   Yes        NaN         NaN    NaN  1968.0          50.0    20.38
# 20  Sedan   Yes      480.0   Automatic    Yes  1968.0          61.0    16.55
# 21  Sedan   Yes      480.0   Automatic    Yes  1798.0          63.0    15.64

# %%
# Out:
# Mean sedan:  18.065371900826445
# Mean hb:  20.507878787878784

# %% [markdown]
# #### 1f) 1. Hypothesis :  Automatic cars mileage is lower than Manual cars. Do the t-tests on data to show if the mean difference is significant

# %% [markdown]
# #### 1g) 2. Hypothesis :  Sedan cars mileage is lower than Hb cars. Do the t-tests on data to show if the mean difference is significant

# %% [markdown]
# #### 1h) Above t-tests assume normal distribution of sample.
# Does automatic car mileage have normal distribution?
# Does manual car mileage have normal distribution?
#
# Does sedan car mileage have normal distribution?
# Does hb car mileage have normal distribution?
