# %%
import pandas as pd

# %%
dünya = pd.read_csv("dünya.csv")
dünya.head()
# Out:
#         Ülke     Gelir     Nüfus  Kişi Başına           KITA
# 0        ABD  20410000   323,766        63039  Kuzey Amerika
# 1        Çin  14090000  1415,045         9957           Asya
# 2    Japonya   5170000   127,185        40649           Asya
# 3    Almanya   4210000    82,293        51158         Avrupa
# 4  İngiltere   2940000    66,573        44162         Avrupa

# %%
dünya[["Ülke","KITA"]].head()
# Out:
#         Ülke           KITA
# 0        ABD  Kuzey Amerika
# 1        Çin           Asya
# 2    Japonya           Asya
# 3    Almanya         Avrupa
# 4  İngiltere         Avrupa

# %%
dünya["Sıralama"] = "tpo 20"

# %%
dünya
# Out:
#                Ülke     Gelir     Nüfus  Kişi Başına           KITA Sıralama
# 0               ABD  20410000   323,766        63039  Kuzey Amerika   tpo 20
# 1               Çin  14090000  1415,045         9957           Asya   tpo 20
# 2           Japonya   5170000   127,185        40649           Asya   tpo 20
# 3           Almanya   4210000    82,293        51158         Avrupa   tpo 20
# 4         İngiltere   2940000    66,573        44162         Avrupa   tpo 20
# 5            Fransa   2930000    65,233        44915         Avrupa   tpo 20
# 6         Hindistan   2850000  1354,051         2104           Asya   tpo 20
# 7            İtalya   2180000     59,29        36768         Avrupa   tpo 20
# 8          Brezilya   2140000   210,867        10148  Güney Amerika   tpo 20
# 9            Kanada   1800000    36,953        48710  Kuzey Amerika   tpo 20
# 10            Rusya   1720000   143,967        11947         Avrupa   tpo 20
# ...

# %%
dünya.insert(2, "gelir düzeyi", "yüksek gelir")

# %%
dünya
# Out:
#                Ülke     Gelir  gelir düzeyi     Nüfus  Kişi Başına  \
# 0               ABD  20410000  yüksek gelir   323,766        63039
# 1               Çin  14090000  yüksek gelir  1415,045         9957
# 2           Japonya   5170000  yüksek gelir   127,185        40649
# 3           Almanya   4210000  yüksek gelir    82,293        51158
# 4         İngiltere   2940000  yüksek gelir    66,573        44162
# 5            Fransa   2930000  yüksek gelir    65,233        44915
# 6         Hindistan   2850000  yüksek gelir  1354,051         2104
# 7            İtalya   2180000  yüksek gelir     59,29        36768
# 8          Brezilya   2140000  yüksek gelir   210,867        10148
# 9            Kanada   1800000  yüksek gelir    36,953        48710
# 10            Rusya   1720000  yüksek gelir   143,967        11947
# 11       GÜney Kore   1690000  yüksek gelir    51,164        33031
# 12          İspanya   1510000  yüksek gelir    46,397        32545
# ...

# %%
dünya["Gelir"]=dünya["Gelir"]/1000000
dünya
# Out:
#                Ülke   Gelir  gelir düzeyi     Nüfus  Kişi Başına  \
# 0               ABD  20.410  yüksek gelir   323,766        63039
# 1               Çin  14.090  yüksek gelir  1415,045         9957
# 2           Japonya   5.170  yüksek gelir   127,185        40649
# 3           Almanya   4.210  yüksek gelir    82,293        51158
# 4         İngiltere   2.940  yüksek gelir    66,573        44162
# 5            Fransa   2.930  yüksek gelir    65,233        44915
# 6         Hindistan   2.850  yüksek gelir  1354,051         2104
# 7            İtalya   2.180  yüksek gelir     59,29        36768
# 8          Brezilya   2.140  yüksek gelir   210,867        10148
# 9            Kanada   1.800  yüksek gelir    36,953        48710
# 10            Rusya   1.720  yüksek gelir   143,967        11947
# 11       GÜney Kore   1.690  yüksek gelir    51,164        33031
# 12          İspanya   1.510  yüksek gelir    46,397        32545
# ...

# %%
dünya["gelir türk lirası"] = dünya["Gelir"]*4.75
dünya
# Out:
#                Ülke   Gelir  gelir düzeyi     Nüfus  Kişi Başına  \
# 0               ABD  20.410  yüksek gelir   323,766        63039
# 1               Çin  14.090  yüksek gelir  1415,045         9957
# 2           Japonya   5.170  yüksek gelir   127,185        40649
# 3           Almanya   4.210  yüksek gelir    82,293        51158
# 4         İngiltere   2.940  yüksek gelir    66,573        44162
# 5            Fransa   2.930  yüksek gelir    65,233        44915
# 6         Hindistan   2.850  yüksek gelir  1354,051         2104
# 7            İtalya   2.180  yüksek gelir     59,29        36768
# 8          Brezilya   2.140  yüksek gelir   210,867        10148
# 9            Kanada   1.800  yüksek gelir    36,953        48710
# 10            Rusya   1.720  yüksek gelir   143,967        11947
# 11       GÜney Kore   1.690  yüksek gelir    51,164        33031
# 12          İspanya   1.510  yüksek gelir    46,397        32545
# ...

# %%
dünya["KITA"].value_counts()
# Out:
# Avrupa           8
# Asya             7
# Kuzey Amerika    3
# Okyanusya        1
# Güney Amerika    1
# Name: KITA, dtype: int64

# %%
nüfüs = pd.read_csv("dünyanüfusu.csv")
nüfüs
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfüs.dropna(how="any")
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfüs.dropna(how="all")
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfüs.dropna(subset=["Doğum oranı"])
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfüs.fillna(1)
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfüs["Doğum oranı"].fillna(1,inplace=True)
nüfüs
# Out:
# 0      1.6
# 1      2.4
# 2      1.9
# 3      2.5
# 4      1.8
# 5      3.7
# 6      5.7
# 7      2.2
# 8      1.7
# 9      2.3
# 10     1.4
# 11     4.6
# 12     1.0
# 13     3.4
# 14     2.0
# 15     6.4
# 16     1.4
# 17     1.7
# 18     2.1
# 19     1.0
# 20     1.9
# 21     2.0
# 22     1.4
# 23     5.2
# 24     2.6
# 25     2.3
# 26     1.2
# 27     1.0
# 28     1.9
# 29     1.3
#       ...
# 203    1.0
# 204    1.0
# 205    1.0
# 206    1.0
# 207    1.0
# 208    1.0
# 209    1.0
# 210    1.0
# 211    1.0
# 212    1.0
# 213    1.0
# 214    1.0
# 215    1.0
# 216    1.0
# 217    1.0
# 218    1.0
# 219    1.0
# 220    1.0
# 221    1.0
# 222    1.0
# 223    1.0
# 224    1.0
# 225    1.0
# 226    1.0
# 227    1.0
# 228    1.0
# 229    1.0
# 230    1.0
# 231    1.0
# 232    1.0
# Name: Doğum oranı, Length: 233, dtype: float64

# %%
nüfüs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 12 columns):
# Sıralama                232 non-null float64
# Ülke                    232 non-null object
# Nüfüs                   232 non-null object
# Yıllık değişim oranı    232 non-null object
# Yıllık değişim          232 non-null object
# Kişi/km2                232 non-null object
# km2                     232 non-null object
# Göçmen                  200 non-null object
# Doğum oranı             233 non-null float64
# Ortalama yaş            200 non-null float64
# Şehirleşme oranı        225 non-null object
# Dünya nüfus oranı       232 non-null object
# dtypes: float64(3), object(9)
# memory usage: 21.9+ KB

# %%
nüfüs.describe
# Out:
# <bound method NDFrame.describe of      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfüs["Sıralama"]=nüfüs["Sıralama"].fillna(1.0)

# %%
nüfüs["Sıralama"]=nüfüs["Sıralama"].astype("int")

# %%
nüfüs
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0           1                     China  1,415,045,928               0.39 %
# 1           2                     India  1,354,051,854               1.11 %
# 2           3                      U.S.    326,766,748               0.71 %
# 3           4                 Indonesia    266,794,980               1.06 %
# 4           5                    Brazil    210,867,954               0.75 %
# 5           6                  Pakistan    200,813,818               1.93 %
# 6           7                   Nigeria    195,875,237               2.61 %
# 7           8                Bangladesh    166,368,149               1.03 %
# 8           9                    Russia    143,964,709              -0.02 %
# 9          10                    Mexico    130,759,074               1.24 %
# 10         11                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfüs.sort_values("Ortalama yaş")
# Out:
#      Sıralama                      Ülke        Nüfüs Yıllık değişim oranı  \
# 56         57                     Niger   22,311,375               3.88 %
# 72         73                      Chad   15,353,184               3.04 %
# 31         32                    Uganda   44,270,563               3.28 %
# 45         46                    Angola   30,774,205               3.32 %
# 61         62                      Mali   19,107,706               3.05 %
# 154       155               Timor-Leste    1,324,094               2.14 %
# 15         16                  DR Congo   84,004,989               3.28 %
# 73         74                   Somalia   15,181,925               2.98 %
# 38         39               Afghanistan   36,373,176               2.37 %
# 23         24                  Tanzania   59,091,392               3.11 %
# 65         66                    Zambia   17,609,178               3.01 %
# 145       146                    Gambia    2,163,765               3.01 %
# ...

# %%
nüfüs.sort_values("Ortalama yaş",ascending=False)
# Out:
#      Sıralama                      Ülke        Nüfüs Yıllık değişim oranı  \
# 22         23                     Italy   59,290,969              -0.12 %
# 16         17                   Germany   82,293,457               0.22 %
# 10         11                     Japan  127,185,332              -0.23 %
# 87         88                  Portugal   10,291,196              -0.37 %
# 177       178                Martinique      385,065               0.04 %
# 140       141                 Lithuania    2,876,475              -0.48 %
# 97         98                   Austria    8,751,820               0.19 %
# 147       148                  Slovenia    2,081,260               0.06 %
# 129       130                   Croatia    4,164,783              -0.59 %
# 104       105                  Bulgaria    7,036,848              -0.67 %
# 103       104                 Hong Kong    7,428,887               0.87 %
# 29         30                     Spain   46,397,452               0.09 %
# ...

# %%
nüfüs.sort_values(["Ortalama yaş","km2"],ascending=[False,True])
# Out:
#      Sıralama                      Ülke        Nüfüs Yıllık değişim oranı  \
# 22         23                     Italy   59,290,969              -0.12 %
# 16         17                   Germany   82,293,457               0.22 %
# 10         11                     Japan  127,185,332              -0.23 %
# 177       178                Martinique      385,065               0.04 %
# 87         88                  Portugal   10,291,196              -0.37 %
# 103       104                 Hong Kong    7,428,887               0.87 %
# 104       105                  Bulgaria    7,036,848              -0.67 %
# 83         84                    Greece   11,142,161              -0.16 %
# 189       190           Channel Islands      166,083               0.47 %
# 147       148                  Slovenia    2,081,260               0.06 %
# 29         30                     Spain   46,397,452               0.09 %
# 129       130                   Croatia    4,164,783              -0.59 %
# ...

# %%
nüfüs.sort_index(ascending=True)
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0           1                     China  1,415,045,928               0.39 %
# 1           2                     India  1,354,051,854               1.11 %
# 2           3                      U.S.    326,766,748               0.71 %
# 3           4                 Indonesia    266,794,980               1.06 %
# 4           5                    Brazil    210,867,954               0.75 %
# 5           6                  Pakistan    200,813,818               1.93 %
# 6           7                   Nigeria    195,875,237               2.61 %
# 7           8                Bangladesh    166,368,149               1.03 %
# 8           9                    Russia    143,964,709              -0.02 %
# 9          10                    Mexico    130,759,074               1.24 %
# 10         11                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfus=pd.read_csv("dünyanüfusu.csv").dropna(how="any")
nüfus
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
nüfus["YAş Sıralama"]=nüfus["Ortalama yaş"].rank(ascending=False).astype("int")
nüfus
# Out:
#      Sıralama                      Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0                     China  1,415,045,928               0.39 %
# 1         2.0                     India  1,354,051,854               1.11 %
# 2         3.0                      U.S.    326,766,748               0.71 %
# 3         4.0                 Indonesia    266,794,980               1.06 %
# 4         5.0                    Brazil    210,867,954               0.75 %
# 5         6.0                  Pakistan    200,813,818               1.93 %
# 6         7.0                   Nigeria    195,875,237               2.61 %
# 7         8.0                Bangladesh    166,368,149               1.03 %
# 8         9.0                    Russia    143,964,709              -0.02 %
# 9        10.0                    Mexico    130,759,074               1.24 %
# 10       11.0                     Japan    127,185,332              -0.23 %
# ...

# %%
x = pd.read_csv("millitakım.csv")
x
# Out:
#     Numara                İsim      Görev Doğum Tarihi  Yaş         Takım  \
# 0        1         Harun Tekin     kaleci    17-6-1989   29         Bursa
# 1       23         Sinan Bolat     kaleci     3-9-1988   29      Royal FC
# 2       12    Serkan Kirintili     kaleci    15-2-1985   33         Konya
# 3        4      Caglar Söyüncü     stoper    23-5-1996   22   Sc Freiburg
# 4       22          Kaan Ayhan     stoper   10-11-1994   23    Düsseldorf
# 5       24      Ertugrul Ersoy     stoper    13-2-1997   21         Bursa
# 6        3  Hasan Ali Kaldirim    sol bek    9-12-1989   28    Fenerbahçe
# 7        6         Ömer Bayram    sol bek    27-7-1991   26       Akhisar
# 8        2    Sener Özbayrakli    sağ bek    23-1-1990   28    Fenerbahçe
# 9       13          Zeki Celik    sağ bek    17-2-1997   21      İstanbul
# 10       5        Okay Yokuslu   önlibero     9-3-1994   24       Trabzon
# 11      15        Mehmet Topal   önlibero     3-3-1986   32    Fenerbahçe
# ...

# %%
takım = x["Takım"] == "Fenerbahçe"
x[takım]
# Out:
#     Numara                İsim     Görev Doğum Tarihi  Yaş       Takım  \
# 6        3  Hasan Ali Kaldirim   sol bek    9-12-1989   28  Fenerbahçe
# 8        2    Sener Özbayrakli   sağ bek    23-1-1990   28  Fenerbahçe
# 11      15        Mehmet Topal  önlibero     3-3-1986   32  Fenerbahçe
#
#        Boy         Ayak  Maç  Gol Milyon Euro
# 6   1,83 m     sol ayak   25  NaN        3.25
# 8   1,71 m     sağ ayak   17  NaN           2
# 11  1,87 m  cift ayakli   78  2.0         2.5

# %%
ön = x["Görev"] == "önlibero"

# %%
x[ön]
# Out:
#     Numara             İsim     Görev Doğum Tarihi  Yaş         Takım     Boy  \
# 10       5     Okay Yokuslu  önlibero     9-3-1994   24       Trabzon  1,91 m
# 11      15     Mehmet Topal  önlibero     3-3-1986   32    Fenerbahçe  1,87 m
# 12      14  Mahmut Tekdemir  önlibero    20-1-1988   30    Başakşehir  1,78 m
# 13      25   Tarkan Serbest  önlibero    19-4-1994   24  Austria Vien  1,84 m
#
#            Ayak  Maç  Gol Milyon Euro
# 10     sağ ayak   14  1.0        7.50
# 11  cift ayakli   78  2.0         2.5
# 12     sağ ayak    5  NaN           2
# 13     sağ ayak    1  NaN         1.5

# %%
x[takım & ön]
# Out:
#     Numara          İsim     Görev Doğum Tarihi  Yaş       Takım     Boy  \
# 11      15  Mehmet Topal  önlibero     3-3-1986   32  Fenerbahçe  1,87 m
#
#            Ayak  Maç  Gol Milyon Euro
# 11  cift ayakli   78  2.0         2.5

# %%
yaş = x["Yaş"]>25
x[yaş]
# Out:
#     Numara                İsim      Görev Doğum Tarihi  Yaş       Takım  \
# 0        1         Harun Tekin     kaleci    17-6-1989   29       Bursa
# 1       23         Sinan Bolat     kaleci     3-9-1988   29    Royal FC
# 2       12    Serkan Kirintili     kaleci    15-2-1985   33       Konya
# 6        3  Hasan Ali Kaldirim    sol bek    9-12-1989   28  Fenerbahçe
# 7        6         Ömer Bayram    sol bek    27-7-1991   26     Akhisar
# 8        2    Sener Özbayrakli    sağ bek    23-1-1990   28  Fenerbahçe
# 11      15        Mehmet Topal   önlibero     3-3-1986   32  Fenerbahçe
# 12      14     Mahmut Tekdemir   önlibero    20-1-1988   30  Başakşehir
# 16      19         Yunus Malli  on numara    24-2-1992   26    Wolsburg
# 23       7       Serdar Gürler  sağ kanat    14-9-1991   26    Osmanlı
# 24      10          Umut Bulut  santrafor    15-3-1983   35     Kayseri
#
#        Boy         Ayak  Maç   Gol Milyon Euro
# 0   1,87 m     sağ ayak    2   NaN         2.5
# ...

# %%
x[yaş|ön]
# Out:
#     Numara                İsim      Görev Doğum Tarihi  Yaş         Takım  \
# 0        1         Harun Tekin     kaleci    17-6-1989   29         Bursa
# 1       23         Sinan Bolat     kaleci     3-9-1988   29      Royal FC
# 2       12    Serkan Kirintili     kaleci    15-2-1985   33         Konya
# 6        3  Hasan Ali Kaldirim    sol bek    9-12-1989   28    Fenerbahçe
# 7        6         Ömer Bayram    sol bek    27-7-1991   26       Akhisar
# 8        2    Sener Özbayrakli    sağ bek    23-1-1990   28    Fenerbahçe
# 10       5        Okay Yokuslu   önlibero     9-3-1994   24       Trabzon
# 11      15        Mehmet Topal   önlibero     3-3-1986   32    Fenerbahçe
# 12      14     Mahmut Tekdemir   önlibero    20-1-1988   30    Başakşehir
# 13      25      Tarkan Serbest   önlibero    19-4-1994   24  Austria Vien
# 16      19         Yunus Malli  on numara    24-2-1992   26      Wolsburg
# 23       7       Serdar Gürler  sağ kanat    14-9-1991   26      Osmanlı
# ...

# %%
x[yaş & ön | takım]
# Out:
#     Numara                İsim     Görev Doğum Tarihi  Yaş       Takım  \
# 6        3  Hasan Ali Kaldirim   sol bek    9-12-1989   28  Fenerbahçe
# 8        2    Sener Özbayrakli   sağ bek    23-1-1990   28  Fenerbahçe
# 11      15        Mehmet Topal  önlibero     3-3-1986   32  Fenerbahçe
# 12      14     Mahmut Tekdemir  önlibero    20-1-1988   30  Başakşehir
#
#        Boy         Ayak  Maç  Gol Milyon Euro
# 6   1,83 m     sol ayak   25  NaN        3.25
# 8   1,71 m     sağ ayak   17  NaN           2
# 11  1,87 m  cift ayakli   78  2.0         2.5
# 12  1,78 m     sağ ayak    5  NaN           2

# %%
m = x["Takım"].isin(["Fenerbahçe","Kayseri"])
x[m]
# Out:
#     Numara                İsim      Görev Doğum Tarihi  Yaş       Takım  \
# 6        3  Hasan Ali Kaldirim    sol bek    9-12-1989   28  Fenerbahçe
# 8        2    Sener Özbayrakli    sağ bek    23-1-1990   28  Fenerbahçe
# 11      15        Mehmet Topal   önlibero     3-3-1986   32  Fenerbahçe
# 18      16         Deniz Türüc  on numara    29-1-1993   25     Kayseri
# 24      10          Umut Bulut  santrafor    15-3-1983   35     Kayseri
#
#        Boy         Ayak  Maç   Gol Milyon Euro
# 6   1,83 m     sol ayak   25   NaN        3.25
# 8   1,71 m     sağ ayak   17   NaN           2
# 11  1,87 m  cift ayakli   78   2.0         2.5
# 18  1,75 m     sol ayak    2   NaN         3.5
# 24  1,84 m     sağ ayak   39  10.0        0.45

# %%
null = x["Gol"].isnull()
x[null]
# Out:
#     Numara                İsim      Görev Doğum Tarihi  Yaş         Takım  \
# 0        1         Harun Tekin     kaleci    17-6-1989   29         Bursa
# 1       23         Sinan Bolat     kaleci     3-9-1988   29      Royal FC
# 2       12    Serkan Kirintili     kaleci    15-2-1985   33         Konya
# 4       22          Kaan Ayhan     stoper   10-11-1994   23    Düsseldorf
# 5       24      Ertugrul Ersoy     stoper    13-2-1997   21         Bursa
# 6        3  Hasan Ali Kaldirim    sol bek    9-12-1989   28    Fenerbahçe
# 7        6         Ömer Bayram    sol bek    27-7-1991   26       Akhisar
# 8        2    Sener Özbayrakli    sağ bek    23-1-1990   28    Fenerbahçe
# 9       13          Zeki Celik    sağ bek    17-2-1997   21      İstanbul
# 12      14     Mahmut Tekdemir   önlibero    20-1-1988   30    Başakşehir
# 13      25      Tarkan Serbest   önlibero    19-4-1994   24  Austria Vien
# 15      11        Yusuf Yazici  on numara    29-1-1997   21       Trabzon
# ...

# %%
notnull = x["Gol"].notnull()
x[notnull]
# Out:
#     Numara             İsim      Görev Doğum Tarihi  Yaş        Takım     Boy  \
# 3        4   Caglar Söyüncü     stoper    23-5-1996   22  Sc Freiburg  1,87 m
# 10       5     Okay Yokuslu   önlibero     9-3-1994   24      Trabzon  1,91 m
# 11      15     Mehmet Topal   önlibero     3-3-1986   32   Fenerbahçe  1,87 m
# 14       8  Oguzhan Özyakup  orta saha    23-9-1992   25     Beşiktaş  1,80 m
# 16      19      Yunus Malli  on numara    24-2-1992   26     Wolsburg  1,79 m
# 17      20      Emre Akbaba  on numara    4-10-1992   25       Alanya  1,80 m
# 22      17     Cengiz Ünder  sağ kanat    14-7-1997   20         Roma  1,73 m
# 24      10       Umut Bulut  santrafor    15-3-1983   35      Kayseri  1,84 m
#
#            Ayak  Maç   Gol Milyon Euro
# 3      sağ ayak   16   1.0          18
# 10     sağ ayak   14   1.0        7.50
# 11  cift ayakli   78   2.0         2.5
# 14     sağ ayak   35   1.0           8
# 16     sağ ayak   18   1.0           9
# ...
